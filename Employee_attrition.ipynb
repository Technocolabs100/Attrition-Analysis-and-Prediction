# %%
import pandas as pd
import seaborn as sns

# %%
dataframe = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
dataframe.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
dataframe.isna()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
numerical_df = pd.get_dummies(dataframe)
numerical_df.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        2          94               3         2  ...
# 1                        3          61               2         2  ...
# 2                        4          92               2         1  ...
# 3                        4          56               3         1  ...
# 4                        1          40               3         1  ...
#
#    JobRole_Research Director  JobRole_Research Scientist  \
# ...

# %%
dataframe['JobSatisfaction'].describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
attrition_perjobsatisfaction  = dataframe.groupby('Attrition').agg({'JobSatisfaction':'mean'})
attrition_perjobsatisfaction.columns =  ['average satisfaction per attrition']
attrition_perjobsatisfaction
# Out:
#            average satisfaction per attrition
# Attrition
# No                                   2.778589
# Yes                                  2.468354

# %%
attrition_perdepartment  = dataframe.groupby(['Attrition','Department']).agg({'Department':'count'})
attrition_perdepartment.columns =  ['attrition per deparment']
attrition_perdepartment  = attrition_perdepartment.reset_index()
attrition_perdepartment
# Out:
#   Attrition              Department  average satisfaction per attrition
# 0        No         Human Resources                                  51
# 1        No  Research & Development                                 828
# 2        No                   Sales                                 354
# 3       Yes         Human Resources                                  12
# 4       Yes  Research & Development                                 133
# 5       Yes                   Sales                                  92

# %%
attrition_df = dataframe['Attrition']== 'Yes'
positive_att = dataframe[attrition_df]

# %%
positive_att['Department'].value_counts()
# Out:
# Research & Development    133
# Sales                      92
# Human Resources            12
# Name: Department, dtype: int64

# %%
positive_att['RelationshipSatisfaction'].describe()
# Out:
# count    237.000000
# mean       2.599156
# std        1.125437
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: RelationshipSatisfaction, dtype: float64

# %%
positive_att['TotalWorkingYears'].describe()
# Out:
# count    237.000000
# mean       8.244726
# std        7.169204
# min        0.000000
# 25%        3.000000
# 50%        7.000000
# 75%       10.000000
# max       40.000000
# Name: TotalWorkingYears, dtype: float64

# %%
attrition_per_education = positive_att.groupby('EducationField').agg({'EducationField':'count'})
attrition_per_education
# Out:
#                   EducationField
# EducationField
# Human Resources                7
# Life Sciences                 89
# Marketing                     35
# Medical                       63
# Other                         11
# Technical Degree              32

# %%
positive_att['DistanceFromHome'].describe()
# Out:
# count    237.000000
# mean      10.632911
# std        8.452525
# min        1.000000
# 25%        3.000000
# 50%        9.000000
# 75%       17.000000
# max       29.000000
# Name: DistanceFromHome, dtype: float64

# %%
Negative_att = dataframe['Attrition'] == 'No'
Negative_att = dataframe[Negative_att]
Negative_att
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
Negative_att['DistanceFromHome'].describe()
# Out:
# count    1233.000000
# mean        8.915653
# std         8.012633
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        13.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
positive_att['YearsInCurrentRole'].describe()
# Out:
# count    237.000000
# mean       2.902954
# std        3.174827
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%        4.000000
# max       15.000000
# Name: YearsInCurrentRole, dtype: float64

# %%
Negative_att['YearsInCurrentRole'].describe()
# Out:
# count    1233.000000
# mean        4.484185
# std         3.649402
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        18.000000
# Name: YearsInCurrentRole, dtype: float64

# %%
positive_att['MonthlyIncome'].describe()
# Out:
# count      237.000000
# mean      4787.092827
# std       3640.210367
# min       1009.000000
# 25%       2373.000000
# 50%       3202.000000
# 75%       5916.000000
# max      19859.000000
# Name: MonthlyIncome, dtype: float64

# %%
Negative_att['MonthlyIncome'].describe()
# Out:
# count     1233.000000
# mean      6832.739659
# std       4818.208001
# min       1051.000000
# 25%       3211.000000
# 50%       5204.000000
# 75%       8834.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
positive_att['NumCompaniesWorked'].describe()
# Out:
# count    237.000000
# mean       2.940928
# std        2.678519
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        5.000000
# max        9.000000
# Name: NumCompaniesWorked, dtype: float64

# %%
Negative_att['NumCompaniesWorked'].describe()
# Out:
# count    1233.00000
# mean        2.64558
# std         2.46009
# min         0.00000
# 25%         1.00000
# 50%         2.00000
# 75%         4.00000
# max         9.00000
# Name: NumCompaniesWorked, dtype: float64

# %%
sns.countplot(data = positive_att, x = 'Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
dataframe['Average time in Company'] = dataframe['TotalWorkingYears'] / dataframe['NumCompaniesWorked']

# %%
dataframe['Attrition'] = dataframe['Attrition'].apply( lambda x:1 if x == 'Yes' else 0)
dataframe['Attrition'].astype = 'int'
dataframe.info()
#dataframe[['Attrition','Age','DailyRate','Education','DistanceFromHome','YearsAtCompany','YearsInCurrentRole','WorkLifeBalance']].corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
positive_att['EducationField'].value_counts()
# Out:
# Life Sciences       89
# Medical             63
# Marketing           35
# Technical Degree    32
# Other               11
# Human Resources      7
# Name: EducationField, dtype: int64
